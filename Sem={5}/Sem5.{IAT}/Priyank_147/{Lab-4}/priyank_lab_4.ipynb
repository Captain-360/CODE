# %%
import pandas as pd
import numpy as np
d=np.random.randint(0,100,(40*5)).reshape(40,5)
rno = [r for r in range(141,181)]
s=pd.DataFrame(data=d,columns=['jsf','flutter','co','iat','iat'],index=rno)
s
# Out:
#      jsf  flutter  co  iat  iat
# 141   47       49  44   80   60
# 142   95        8  51   19   77
# 143   98       45  41    5   40
# 144   28       95  67   60   52
# 145   89       94  69    4   36
# 146   43       46  99    6    7
# 147   97       53  84   88   77
# 148   49       56  43    2   50
# 149   85       56  65   17   33
# 150   94        1  31   40   90
# 151   33       30  27   43   75
# 152   70       46   8   31   11
# 153   90       89  49   22   40
# 154   45       15  65   50   16
# 155   81       75  76   41   14
# 156   43       57  39   85   15
# 157    0       23  60   98   32
# 158   78       27  87   25   84
# 159   98       23  64   20   94
# 160   16       75  42   50   97
# 161   41       63  59   90   43
# 162   26       18  32   64   13
# 163   15       22  76   85   74
# 164   81       35  89   49   29
# 165   37        1  76    7   50
# 166   69       49  43   76   19
# 167   73       17  23   15   28
# 168   55       90  69   77   25
# ...

# %%
c = ns["iat"][ns['iat']<35]
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 c = ns["iat"][ns['iat']<35]
#       2 c
#
# NameError: name 'ns' is not defined
